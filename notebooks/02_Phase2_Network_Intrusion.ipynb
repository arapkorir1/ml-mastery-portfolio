# %% [markdown]
# # 🛡️ Phase 2: Classification & Decision Boundaries — Network Intrusion Detection
#
# > **Goal:** Classify network traffic as **Normal (0)** or **Malicious (1)** using three algorithms.
# > **Skills covered:** Classification theory, decision boundaries, KNN, Logistic Regression, SVM, confusion matrices, precision/recall/F1, ROC curves.
